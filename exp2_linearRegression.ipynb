# %%
import pandas as pd

# %%
data=pd.read_csv('tvmarketing.csv')

# %%
data.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
data.tail()
# Out:
#         TV  Sales
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4

# %%
data.describe()
# Out:
#                TV       Sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
data.shape
# Out:
# (200, 2)

# %%
data.plot(x='TV',y='Sales', kind='scatter');

# %%
x=data['TV']

# %%
x.head()
# Out:
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# Name: TV, dtype: float64

# %%
y=data['Sales']

# %%
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: Sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split 
x_tain,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=0000)

# %%
x_tain.head()
# Out:
# 131    265.2
# 96     197.6
# 181    218.5
# 19     147.3
# 153    171.3
# Name: TV, dtype: float64

# %%
x_tain.count()
# Out:
# 140

# %%
import numpy as np 
x_tain=x_tain[:,np.newaxis]
x_test=x_test[:,np.newaxis]
from sklearn.linear_model import LinearRegression
# Out:
# C:\Users\PRIYANSHU SINGH\AppData\Local\Temp\ipykernel_29472\3926521574.py:2: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x_tain=x_tain[:,np.newaxis]
# C:\Users\PRIYANSHU SINGH\AppData\Local\Temp\ipykernel_29472\3926521574.py:3: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x_test=x_test[:,np.newaxis]

# %%
model=LinearRegression()

# %%
model.fit(x_tain,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_,model.coef_
# Out:
# (7.310810165411681, array([0.04581434]))

# %%
y_pred=model.predict(x_test)

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 7.497479593464674

# %%
r_squared=r2_score(y_test,y_pred)
r_squared
# Out:
# 0.725606346597073

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test,y_pred,c='blue')
plt.xlabel('Y test')
plt.ylabel('y-predicted ')
plt.grid();

# %%
data.corr()
# Out:
#              TV     Sales
# TV     1.000000  0.782224
# Sales  0.782224  1.000000
